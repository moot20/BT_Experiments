# %% [markdown]
# # Energy Consumption Analysis

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Load the CSV file
file_path = './energy_consumption_log.csv'
data = pd.read_csv(file_path)

# Convert Time_elapsed_seconds to seconds
def convert_time_to_seconds(time_str):
    parts = time_str.split(':')
    if len(parts) == 3:
        hours, minutes, seconds = parts
    else:
        hours = 0
        minutes, seconds = parts
    total_seconds = int(hours) * 3600 + int(minutes) * 60 + float(seconds)
    return total_seconds

data['Time_elapsed_seconds'] = data['Time_elapsed_seconds'].apply(convert_time_to_seconds)

# Filter the data for the specified files
svm_py_data = data[data['File'] == 'SVM.py']
svm_r_data = data[data['File'] == 'SVM.R']
rf_py_data = data[data['File'] == 'RF.py']
rf_r_data = data[data['File'] == 'RF.R']

# %%
# Calculate summary statistics for each group
svm_py_summary = svm_py_data.describe()
svm_r_summary = svm_r_data.describe()
rf_py_summary = rf_py_data.describe()
rf_r_summary = rf_r_data.describe()

# Print summary statistics
print("SVM.py Summary Statistics")
print(svm_py_summary)
print("\nSVM.R Summary Statistics")
print(svm_r_summary)
print("\nRF.py Summary Statistics")
print(rf_py_summary)
print("\nRF.R Summary Statistics")
print(rf_r_summary)
# Out:
# SVM.py Summary Statistics
#             Run  Energy_pkg_Joules  Energy_psys_Joules  Time_elapsed_seconds
# count  50.00000          50.000000           50.000000             50.000000
# mean   25.50000          16.516600           23.404000              0.947525
# std    14.57738           0.575122            0.829458              0.029084
# min     1.00000          15.520000           22.110000              0.897619
# 25%    13.25000          16.122500           22.802500              0.930165
# 50%    25.50000          16.485000           23.405000              0.946785
# 75%    37.75000          16.817500           23.787500              0.962462
# max    50.00000          18.340000           25.910000              1.023651
#
# SVM.R Summary Statistics
#             Run  Energy_pkg_Joules  Energy_psys_Joules  Time_elapsed_seconds
# count  50.00000          50.000000           50.000000             50.000000
# mean   25.50000           3.365200            4.820600              0.194834
# std    14.57738           0.200349            0.288263              0.009274
# min     1.00000           3.020000            4.360000              0.179688
# 25%    13.25000           3.212500            4.602500              0.188496
# 50%    25.50000           3.345000            4.770000              0.193443
# 75%    37.75000           3.450000            4.965000              0.198391
# max    50.00000           4.010000            5.740000              0.219619
#
# RF.py Summary Statistics
#             Run  Energy_pkg_Joules  Energy_psys_Joules  Time_elapsed_seconds
# count  50.00000          50.000000           50.000000             50.000000
# mean   25.50000          18.896600           26.884200              1.106365
# std    14.57738           0.899679            1.216272              0.037484
# min     1.00000          16.510000           23.680000              1.005352
# 25%    13.25000          18.325000           26.092500              1.077816
# 50%    25.50000          18.845000           26.740000              1.103863
# 75%    37.75000          19.380000           27.705000              1.137688
# max    50.00000          20.980000           29.970000              1.182954
#
# RF.R Summary Statistics
#             Run  Energy_pkg_Joules  Energy_psys_Joules  Time_elapsed_seconds
# count  50.00000           50.00000           50.000000             50.000000
# mean   25.50000            3.37060            4.820600              0.195863
# std    14.57738            0.21252            0.283674              0.010260
# min     1.00000            2.99000            4.330000              0.174436
# 25%    13.25000            3.21250            4.605000              0.188884
# 50%    25.50000            3.35000            4.825000              0.196213
# 75%    37.75000            3.51000            5.027500              0.202548
# max    50.00000            4.15000            5.830000              0.221773

# %%
# Plot comparison of Energy_pkg_Joules
plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
plt.boxplot([svm_py_data['Energy_pkg_Joules'], svm_r_data['Energy_pkg_Joules']],
            tick_labels=['SVM.py', 'SVM.R'])
plt.title('Energy_pkg_Joules Comparison for SVM')

plt.subplot(1, 2, 2)
plt.boxplot([rf_py_data['Energy_pkg_Joules'], rf_r_data['Energy_pkg_Joules']],
            tick_labels=['RF.py', 'RF.R'])
plt.title('Energy_pkg_Joules Comparison for RF')

plt.tight_layout()
plt.show()

# %%
# Plot comparison of Energy_psys_Joules
plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
plt.boxplot([svm_py_data['Energy_psys_Joules'], svm_r_data['Energy_psys_Joules']],
            tick_labels=['SVM.py', 'SVM.R'])
plt.title('Energy_psys_Joules Comparison for SVM')

plt.subplot(1, 2, 2)
plt.boxplot([rf_py_data['Energy_psys_Joules'], rf_r_data['Energy_psys_Joules']],
            tick_labels=['RF.py', 'RF.R'])
plt.title('Energy_psys_Joules Comparison for RF')

plt.tight_layout()
plt.show()

# %%
# Plot comparison of Time_elapsed_seconds
plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
plt.boxplot([svm_py_data['Time_elapsed_seconds'], svm_r_data['Time_elapsed_seconds']],
            tick_labels=['SVM.py', 'SVM.R'])
plt.title('Time_elapsed_seconds Comparison for SVM')

plt.subplot(1, 2, 2)
plt.boxplot([rf_py_data['Time_elapsed_seconds'], rf_r_data['Time_elapsed_seconds']],
            tick_labels=['RF.py', 'RF.R'])
plt.title('Time_elapsed_seconds Comparison for RF')

plt.tight_layout()
plt.show()

# %%
# Plot comparison of Memory_used_kb
plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
plt.boxplot([svm_py_data['Memory_used_kb'], svm_r_data['Memory_used_kb']],
            tick_labels=['SVM.py', 'SVM.R'])
plt.title('Memory_used_kb Comparison for SVM')

plt.subplot(1, 2, 2)
plt.boxplot([rf_py_data['Memory_used_kb'], rf_r_data['Memory_used_kb']],
            tick_labels=['RF.py', 'RF.R'])
plt.title('Memory_used_kb Comparison for RF')

plt.tight_layout()
plt.show()
